# %%
#Load required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import glob
import re
import emoji
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
# import imblearn
# from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import nltk
from nltk.corpus import wordnet
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer

from sklearn import preprocessing

# %%
#Loading the raw data

# %%
import pandas as pd
df=pd.read_excel("./BotReliabilityRaw.xlsx")
df
# Out:
#       Group                                              Tweet  RA1 Intent  \
# 0         1  I wanna say a dollar more even being just righ...      others
# 1         1  Hope your having a good day Gidgett. Have a wo...     support
# 2         1  I will take deep breaths find a great hobby to...      others
# 3         1  Hope everyone is doing great I found out the o...     support
# 4         1  Go to Walmart & pick up an empty spray bottle ...      others
# ...     ...                                                ...         ...
# 82043    X8  oh I feel you on the morning coffee not being ...    cravings
# 82044    X8                             That's awesome!!!!! :)     support
# 82045    X8  so far it's been a good day. no strong craving...   smokefree
# 82046    X8  I know. Me too. Its just so cold here!! Time t...  weightGain
# 82047    X8  good. I'm home now too. Relaxing a bit before ...      others
#
#        RA2 Intent Final Intent
# 0          others       others
# 1         support      support
# 2          others       others
# 3         support      support
# 4          others       others
# ...           ...          ...
# 82043    cravings     cravings
# 82044      others       others
# 82045   smokefree    smokefree
# 82046  weightGain   weightGain
# 82047      others       others
#
# [82048 rows x 5 columns]

# %%
df.rename(columns={'Final Intent': 'intent'}, inplace=True)
df['intent'] = df['intent'].str.strip().str.lower()
df = df[['Group','Tweet','intent']]
df
# Out:
#       Group                                              Tweet      intent
# 0         1  I wanna say a dollar more even being just righ...      others
# 1         1  Hope your having a good day Gidgett. Have a wo...     support
# 2         1  I will take deep breaths find a great hobby to...      others
# 3         1  Hope everyone is doing great I found out the o...     support
# 4         1  Go to Walmart & pick up an empty spray bottle ...      others
# ...     ...                                                ...         ...
# 82043    X8  oh I feel you on the morning coffee not being ...    cravings
# 82044    X8                             That's awesome!!!!! :)      others
# 82045    X8  so far it's been a good day. no strong craving...   smokefree
# 82046    X8  I know. Me too. Its just so cold here!! Time t...  weightgain
# 82047    X8  good. I'm home now too. Relaxing a bit before ...      others
#
# [82048 rows x 3 columns]

# %%
#Getting rid of Nan Values

# %%
df=df.dropna().reset_index(drop=True)
df
# Out:
#       Group                                              Tweet      intent
# 0         1  I wanna say a dollar more even being just righ...      others
# 1         1  Hope your having a good day Gidgett. Have a wo...     support
# 2         1  I will take deep breaths find a great hobby to...      others
# 3         1  Hope everyone is doing great I found out the o...     support
# 4         1  Go to Walmart & pick up an empty spray bottle ...      others
# ...     ...                                                ...         ...
# 81862    X8  oh I feel you on the morning coffee not being ...    cravings
# 81863    X8                             That's awesome!!!!! :)      others
# 81864    X8  so far it's been a good day. no strong craving...   smokefree
# 81865    X8  I know. Me too. Its just so cold here!! Time t...  weightgain
# 81866    X8  good. I'm home now too. Relaxing a bit before ...      others
#
# [81867 rows x 3 columns]

# %%
df=df.drop_duplicates(subset='Tweet')
df=df.reset_index(drop=True)
df
# Out:
#       Group                                              Tweet      intent
# 0         1  I wanna say a dollar more even being just righ...      others
# 1         1  Hope your having a good day Gidgett. Have a wo...     support
# 2         1  I will take deep breaths find a great hobby to...      others
# 3         1  Hope everyone is doing great I found out the o...     support
# 4         1  Go to Walmart & pick up an empty spray bottle ...      others
# ...     ...                                                ...         ...
# 77351    X8  oh I feel you on the morning coffee not being ...    cravings
# 77352    X8                             That's awesome!!!!! :)      others
# 77353    X8  so far it's been a good day. no strong craving...   smokefree
# 77354    X8  I know. Me too. Its just so cold here!! Time t...  weightgain
# 77355    X8  good. I'm home now too. Relaxing a bit before ...      others
#
# [77356 rows x 3 columns]

# %%
#Dividing test set and rest of the intent set

# %%
import pandas as pd
df_check=df
# Ensure the group column is treated correctly
df_check.iloc[:, 0] = pd.to_numeric(df.iloc[:, 0], errors='coerce')  # Convert numeric, set non-numeric to NaN

# Filter test set (groups 30 to 36)
test = df[df_check.iloc[:, 0].between(30, 36, inclusive="both")]

# Rest of the data (everything else)
intents = df[~df.index.isin(test.index)]

# Display results
print(f"Test Set Size: {test.shape[0]}")
print(f"Intent Set Size: {intents.shape[0]}")
# Out:
# Test Set Size: 15207
# Intent Set Size: 62149

# %%
od_df=pd.read_excel("./BotTesting_Extra_to Shagoto.xlsx")
od_df
# Out:
#                                                 Tweet Correct Intent
# 0                  Step 1 is too strong makes me sick         NRT_OD
# 1                  Using the patch now but too potent         NRT_OD
# 2   Step 1 was too strong and made me nauseous and...         NRT_OD
# 3   The high dose was too much was having an overdose         NRT_OD
# 4         Don't smoke with the patch you can get sick         NRT_OD
# 5       I feel better after changing to a lower patch         NRT_OD
# 6   I changed to the lower patch because it was to...         NRT_OD
# 7               The patch might be too strong for you         NRT_OD
# 8   I found out the patch was too strong for my bo...         NRT_OD
# 9   I alternate gum with regular mints so it isn't...         NRT_OD
# 10  After I put the patch on I yanked it off becau...         NRT_OD
# 11  They gave me 21mg patches when they should hav...         NRT_OD
# 12  I skipped the step 1 patches because I couldn'...         NRT_OD
# 13  What is wrong with these patches? They make my...         NRT_OD
# 14               I'm definently oding on these things         NRT_OD
# 15                   Can you overdose on the patches?         NRT_OD
# 16             I might need a lower dose of the patch         NRT_OD
# 17                The gum has too much nicotine in it         NRT_OD
# 18                        The lozenges are too strong         NRT_OD
# 19  The jolt of nicotine I get from chewing the gu...         NRT_OD
# 20  I swallow some of the lozenge and the taste of...         NRT_OD
# 21  Smoke free, but doing it without the patch as ...         NRT_OD
# 22             There is too much nicotine in that gum         NRT_OD
# 23  Does anyone else feel that the lozenges are to...         NRT_OD
# 24      I wish they hadn't given me such a strong gum         NRT_OD
# 25     I need a weaker lozenge, this one is too much.         NRT_OD
# 26  I wish I had more of the 14mg patch rather tha...         NRT_OD
# 27                     These lozenges are very potent         NRT_OD
# 28  Does anyone else have a potency problem with t...         NRT_OD
# 29          The strength of these patches is too much         NRT_OD
# 30  There is an excesive amount of nicotine in the...         NRT_OD
# 31             Crazy amounts of nicotine in this gum.         NRT_OD
# 32            Patches are the strongest I've ever had         NRT_OD
# 33                     Step 2 was much better than 1.         NRT_OD
# 34  I need to go to step 2 because these Step 1 pa...         NRT_OD
# 35          I think I overdosed on the gum last night         NRT_OD
# 36                  Can I overdose from the lozenges?         NRT_OD
# 37  I am really thinking that these patches might ...         NRT_OD
# 38          Maybe the patches are too strong for you?         NRT_OD
# 39  Don't use the patches if they are too strong f...         NRT_OD
# 40      I think I need to step down with the patches.         NRT_OD
# 41  I used the patches yesterday and I felt sick b...         NRT_OD
# 42  The lozenges have a very strong taste of nicot...         NRT_OD
# 43  I think the dosage of the patch is too strong ...         NRT_OD
# 44  If I chew a lot of gum I feel sick. Is it norm...         NRT_OD
# 45  I`m feeling dizzy with the patch on. Maybe it ...         NRT_OD
# 46  Are you using the lozenges too? Don't you thin...         NRT_OD
# 47                   I think 21mg is too much for me.         NRT_OD
# 48  I am going to talk to my doctor to go to step ...         NRT_OD
# 49  The gum leaves a strong cigarette taste, I thi...         NRT_OD
# 50     I'm getting too much nicotine from the patches         NRT_OD
# 51  Is there a way to get less nicotine from the l...         NRT_OD
# 52       Can I cut a lozenge in half? One is too much         NRT_OD
# 53  I might need to use just half a patch until I'...         NRT_OD
# 54          I used too many pieces of gum at one time         NRT_OD
# 55  I need to slow down on these lozenges, I think...         NRT_OD
# 56  How much nicotine is too much? I'm worried abo...         NRT_OD
# 57                     These patches are too powerful         NRT_OD
# 58                              I need weaker patches         NRT_OD
# 59  When do you know if you've gotten too much nic...         NRT_OD

# %%
od_df.rename(columns={'Correct Intent': 'intent'}, inplace=True)
od_df['intent'] = od_df['intent'].str.strip().str.lower()
od_df = od_df[['Tweet','intent']]
od_df
# Out:
#                                                 Tweet  intent
# 0                  Step 1 is too strong makes me sick  nrt_od
# 1                  Using the patch now but too potent  nrt_od
# 2   Step 1 was too strong and made me nauseous and...  nrt_od
# 3   The high dose was too much was having an overdose  nrt_od
# 4         Don't smoke with the patch you can get sick  nrt_od
# 5       I feel better after changing to a lower patch  nrt_od
# 6   I changed to the lower patch because it was to...  nrt_od
# 7               The patch might be too strong for you  nrt_od
# 8   I found out the patch was too strong for my bo...  nrt_od
# 9   I alternate gum with regular mints so it isn't...  nrt_od
# 10  After I put the patch on I yanked it off becau...  nrt_od
# 11  They gave me 21mg patches when they should hav...  nrt_od
# 12  I skipped the step 1 patches because I couldn'...  nrt_od
# 13  What is wrong with these patches? They make my...  nrt_od
# 14               I'm definently oding on these things  nrt_od
# 15                   Can you overdose on the patches?  nrt_od
# 16             I might need a lower dose of the patch  nrt_od
# 17                The gum has too much nicotine in it  nrt_od
# 18                        The lozenges are too strong  nrt_od
# 19  The jolt of nicotine I get from chewing the gu...  nrt_od
# 20  I swallow some of the lozenge and the taste of...  nrt_od
# 21  Smoke free, but doing it without the patch as ...  nrt_od
# 22             There is too much nicotine in that gum  nrt_od
# 23  Does anyone else feel that the lozenges are to...  nrt_od
# 24      I wish they hadn't given me such a strong gum  nrt_od
# 25     I need a weaker lozenge, this one is too much.  nrt_od
# 26  I wish I had more of the 14mg patch rather tha...  nrt_od
# 27                     These lozenges are very potent  nrt_od
# 28  Does anyone else have a potency problem with t...  nrt_od
# 29          The strength of these patches is too much  nrt_od
# 30  There is an excesive amount of nicotine in the...  nrt_od
# 31             Crazy amounts of nicotine in this gum.  nrt_od
# 32            Patches are the strongest I've ever had  nrt_od
# 33                     Step 2 was much better than 1.  nrt_od
# 34  I need to go to step 2 because these Step 1 pa...  nrt_od
# 35          I think I overdosed on the gum last night  nrt_od
# 36                  Can I overdose from the lozenges?  nrt_od
# 37  I am really thinking that these patches might ...  nrt_od
# 38          Maybe the patches are too strong for you?  nrt_od
# 39  Don't use the patches if they are too strong f...  nrt_od
# 40      I think I need to step down with the patches.  nrt_od
# 41  I used the patches yesterday and I felt sick b...  nrt_od
# 42  The lozenges have a very strong taste of nicot...  nrt_od
# 43  I think the dosage of the patch is too strong ...  nrt_od
# 44  If I chew a lot of gum I feel sick. Is it norm...  nrt_od
# 45  I`m feeling dizzy with the patch on. Maybe it ...  nrt_od
# 46  Are you using the lozenges too? Don't you thin...  nrt_od
# 47                   I think 21mg is too much for me.  nrt_od
# 48  I am going to talk to my doctor to go to step ...  nrt_od
# 49  The gum leaves a strong cigarette taste, I thi...  nrt_od
# 50     I'm getting too much nicotine from the patches  nrt_od
# 51  Is there a way to get less nicotine from the l...  nrt_od
# 52       Can I cut a lozenge in half? One is too much  nrt_od
# 53  I might need to use just half a patch until I'...  nrt_od
# 54          I used too many pieces of gum at one time  nrt_od
# 55  I need to slow down on these lozenges, I think...  nrt_od
# 56  How much nicotine is too much? I'm worried abo...  nrt_od
# 57                     These patches are too powerful  nrt_od
# 58                              I need weaker patches  nrt_od
# 59  When do you know if you've gotten too much nic...  nrt_od

# %%
duplicates = od_df[od_df.duplicated(subset=['Tweet'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [Tweet, intent]
# Index: []

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

train_od, test_od = train_test_split(od_df, test_size=0.2, random_state=42)

# Append split data
intents = pd.concat([intents, train_od], ignore_index=True)
test = pd.concat([test, test_od], ignore_index=True)

# %%
intents["intent"]=intents.intent.str.lower().str.replace("'|’","")
intents["intent"]=np.where(intents.intent=="dreams","nrt_dreams",\
                  np.where(intents.intent=="smokeless","smokingless",\
                  np.where(intents.intent=="others","noresponse",\
                  np.where(intents.intent=="costs","savingmoney",intents.intent))))

# # Converting the codes to appropriate categories using a dictionary

from sklearn import preprocessing
le = preprocessing.LabelEncoder()

intents['encoded_intent'] = le.fit_transform(intents['intent'].tolist())
print(intents['intent'].groupby(intents['encoded_intent']).unique().apply(pd.Series))

print('size',intents.groupby(["intent"]).size())

intents.head()
# Out:
#                                   0
# encoded_intent
# 0                          cigsmell
# 1                          cravings
# 2                             ecigs
# 3                              fail
# 4                         greetings
# 5                            health
# 6                        noresponse
# 7                     nrt_don'twork
# 8                        nrt_dreams
# 9                      nrt_howtouse
# 10                      nrt_itworks
# 11              nrt_mouthirritation
# 12                     nrt_nauseous
# 13                           nrt_od
# 14               nrt_skinirritation
# 15                   nrt_stickissue
# 16                         quitdate
# 17                      savingmoney
# 18                           scared
# 19                        smokefree
# 20                      smokingless
# 21                           stress
# 22                          support
# 23                        tiredness
# 24                       weightgain
# size intent
# cigsmell                 437
# cravings                1928
# ecigs                    273
# fail                    1032
# greetings               2438
# health                  1130
# noresponse             34791
# nrt_don'twork            409
# nrt_dreams               344
# nrt_howtouse             472
# nrt_itworks              820
# nrt_mouthirritation      186
# nrt_nauseous             163
# nrt_od                   108
# nrt_skinirritation       206
# nrt_stickissue           251
# quitdate                1706
# savingmoney              607
# scared                   391
# smokefree               4096
# smokingless              380
# stress                   677
# support                 8440
# tiredness                204
# weightgain               708
# dtype: int64
#   Group                                              Tweet      intent  \
# 0   1.0  I wanna say a dollar more even being just righ...  noresponse
# 1   1.0  Hope your having a good day Gidgett. Have a wo...     support
# 2   1.0  I will take deep breaths find a great hobby to...  noresponse
# 3   1.0  Hope everyone is doing great I found out the o...     support
# 4   1.0  Go to Walmart & pick up an empty spray bottle ...  noresponse
#
#    encoded_intent
# 0               6
# 1              22
# 2               6
# 3              22
# 4               6

# %%
intents['intent'].value_counts()
# Out:
# intent
# noresponse             34791
# support                 8440
# smokefree               4096
# greetings               2438
# cravings                1928
# quitdate                1706
# health                  1130
# fail                    1032
# nrt_itworks              820
# weightgain               708
# stress                   677
# savingmoney              607
# nrt_howtouse             472
# cigsmell                 437
# nrt_don'twork            409
# scared                   391
# smokingless              380
# nrt_dreams               344
# ecigs                    273
# nrt_stickissue           251
# nrt_skinirritation       206
# tiredness                204
# nrt_mouthirritation      186
# nrt_nauseous             163
# nrt_od                   108
# Name: count, dtype: int64

# %%
##Split the train and eval

# %%
train_df, val_df = train_test_split(
    intents,  # Split the entire DataFrame
    test_size=0.25,  # 25% for validation
    random_state=42,  # Reproducibility
    stratify=intents['encoded_intent']  # Ensure class balance
)

# %%
train_df['intent'].value_counts()
# Out:
# intent
# noresponse             26093
# support                 6330
# smokefree               3072
# greetings               1828
# cravings                1446
# quitdate                1279
# health                   847
# fail                     774
# nrt_itworks              615
# weightgain               531
# stress                   508
# savingmoney              455
# nrt_howtouse             354
# cigsmell                 328
# nrt_don'twork            307
# scared                   293
# smokingless              285
# nrt_dreams               258
# ecigs                    205
# nrt_stickissue           188
# nrt_skinirritation       155
# tiredness                153
# nrt_mouthirritation      140
# nrt_nauseous             122
# nrt_od                    81
# Name: count, dtype: int64

# %%
val_df['intent'].value_counts()
# Out:
# intent
# noresponse             8698
# support                2110
# smokefree              1024
# greetings               610
# cravings                482
# quitdate                427
# health                  283
# fail                    258
# nrt_itworks             205
# weightgain              177
# stress                  169
# savingmoney             152
# nrt_howtouse            118
# cigsmell                109
# nrt_don'twork           102
# scared                   98
# smokingless              95
# nrt_dreams               86
# ecigs                    68
# nrt_stickissue           63
# tiredness                51
# nrt_skinirritation       51
# nrt_mouthirritation      46
# nrt_nauseous             41
# nrt_od                   27
# Name: count, dtype: int64

# %%
#Renaming test intents

# %%
test["intent"]=test.intent.str.lower().str.replace("'|’","")
test["intent"]=np.where(test.intent=="dreams","nrt_dreams",\
                  np.where(test.intent=="smokeless","smokingless",\
                  np.where(test.intent=="others","noresponse",\
                  np.where(test.intent=="costs","savingmoney",test.intent))))

# # Converting the codes to appropriate categories using a dictionary

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
test['encoded_intent'] = le.fit_transform(test['intent'].tolist())
print(test['intent'].groupby(test['encoded_intent']).unique().apply(pd.Series))
test.head()
# Out:
#                                   0
# encoded_intent
# 0                          cigsmell
# 1                          cravings
# 2                             ecigs
# 3                              fail
# 4                         greetings
# 5                            health
# 6                        noresponse
# 7                     nrt_don'twork
# 8                        nrt_dreams
# 9                      nrt_howtouse
# 10                      nrt_itworks
# 11              nrt_mouthirritation
# 12                     nrt_nauseous
# 13                           nrt_od
# 14               nrt_skinirritation
# 15                   nrt_stickissue
# 16                         quitdate
# 17                      savingmoney
# 18                           scared
# 19                        smokefree
# 20                      smokingless
# 21                           stress
# 22                          support
# 23                        tiredness
# 24                       weightgain
#   Group                                              Tweet      intent  \
# 0  30.0  Celebrate You\n\nStayingÂ smokefreeÂ is a big ...     support
# 1  30.0  Busy i took a nap after my girls got their hai...  noresponse
# 2  30.0  You got this just keep your gum close by and m...     support
# 3  30.0  Q: How do you keep your husband from reading y...  noresponse
# 4  30.0                                 Hot and humid yuck  noresponse
#
#    encoded_intent
# 0              22
# 1               6
# 2              22
# 3               6
# 4               6

# %%
test=test.reset_index(drop=True)
test
# Out:
#       Group                                              Tweet      intent  \
# 0      30.0  Celebrate You\n\nStayingÂ smokefreeÂ is a big ...     support
# 1      30.0  Busy i took a nap after my girls got their hai...  noresponse
# 2      30.0  You got this just keep your gum close by and m...     support
# 3      30.0  Q: How do you keep your husband from reading y...  noresponse
# 4      30.0                                 Hot and humid yuck  noresponse
# ...     ...                                                ...         ...
# 15214   NaN  I am going to talk to my doctor to go to step ...      nrt_od
# 15215   NaN  I skipped the step 1 patches because I couldn'...      nrt_od
# 15216   NaN                     These patches are too powerful      nrt_od
# 15217   NaN  Are you using the lozenges too? Don't you thin...      nrt_od
# 15218   NaN     I'm getting too much nicotine from the patches      nrt_od
#
#        encoded_intent
# 0                  22
# 1                   6
# 2                  22
# 3                   6
# 4                   6
# ...               ...
# 15214              13
# 15215              13
# 15216              13
# 15217              13
# 15218              13
#
# [15219 rows x 4 columns]

# %%
test['intent'].value_counts()
# Out:
# intent
# noresponse             9664
# support                1983
# smokefree               818
# greetings               490
# quitdate                318
# cravings                267
# health                  265
# weightgain              167
# fail                    152
# stress                  148
# nrt_itworks             135
# nrt_howtouse            105
# savingmoney              90
# nrt_stickissue           83
# scared                   83
# cigsmell                 76
# ecigs                    73
# nrt_don'twork            72
# nrt_dreams               54
# tiredness                43
# nrt_skinirritation       35
# smokingless              33
# nrt_nauseous             23
# nrt_mouthirritation      21
# nrt_od                   21
# Name: count, dtype: int64

# %%
train_df=train_df.reset_index(drop=True)
train_df=train_df[['Tweet','intent']]
train_df
# Out:
#                                                    Tweet      intent
# 0                                    Yep too many times!  noresponse
# 1      You are still learning to quit. Figure out wha...  noresponse
# 2      Good evening ladies! What is that lovely fragr...   greetings
# 3                           you can probably email them.  noresponse
# 4       Sry u had to go thru all that we have to deal...  noresponse
# ...                                                  ...         ...
# 46642                      Lol...I do that all the time!  noresponse
# 46643  Goin good so far fixing to get up an get ready...  noresponse
# 46644                      ooh la la lol.. That's sweet.  noresponse
# 46645  Hey hey hey. How are you? Still learning Twitt...   greetings
# 46646  Enjoy it one last day. Tomorrow we move on to ...    quitdate
#
# [46647 rows x 2 columns]

# %%
val_df=val_df.reset_index(drop=True)
val_df=val_df[['Tweet','intent']]
val_df
# Out:
#                                                    Tweet       intent
# 0                                                  Lol..   noresponse
# 1      Isn't that the truth lol I never had a filter ...   noresponse
# 2      Took it off last night but still sleep eluded ...   nrt_dreams
# 3                  tweeting has helped and has been fun!   noresponse
# 4                                I am still on the patch  nrt_itworks
# ...                                                  ...          ...
# 15545                I know I can, I'm just scared haha.       scared
# 15546  Do be healthier/ don't want to because it's ha...       health
# 15547  I'm really irritable and depressed today. And ...    tiredness
# 15548  Still a non smoker here too. keep trying carey...    smokefree
# 15549  Went back and read from the 1st day this group...   noresponse
#
# [15550 rows x 2 columns]

# %%
test=test.reset_index(drop=True)
test=test[['Tweet','intent']]
test
# Out:
#                                                    Tweet      intent
# 0      Celebrate You\n\nStayingÂ smokefreeÂ is a big ...     support
# 1      Busy i took a nap after my girls got their hai...  noresponse
# 2      You got this just keep your gum close by and m...     support
# 3      Q: How do you keep your husband from reading y...  noresponse
# 4                                     Hot and humid yuck  noresponse
# ...                                                  ...         ...
# 15214  I am going to talk to my doctor to go to step ...      nrt_od
# 15215  I skipped the step 1 patches because I couldn'...      nrt_od
# 15216                     These patches are too powerful      nrt_od
# 15217  Are you using the lozenges too? Don't you thin...      nrt_od
# 15218     I'm getting too much nicotine from the patches      nrt_od
#
# [15219 rows x 2 columns]

# %%
train_df.to_csv("nrt_training_all_intent.csv")
val_df.to_csv("nrt_validation_all_intent.csv")
test.to_csv("nrt_test_with_all_intent.csv")

# %%
train_df['intent'].value_counts()
# Out:
# intent
# noresponse             26093
# support                 6330
# smokefree               3072
# greetings               1828
# cravings                1446
# quitdate                1279
# health                   847
# fail                     774
# nrt_itworks              615
# weightgain               531
# stress                   508
# savingmoney              455
# nrt_howtouse             354
# cigsmell                 328
# nrt_don'twork            307
# scared                   293
# smokingless              285
# nrt_dreams               258
# ecigs                    205
# nrt_stickissue           188
# nrt_skinirritation       155
# tiredness                153
# nrt_mouthirritation      140
# nrt_nauseous             122
# nrt_od                    81
# Name: count, dtype: int64

# %%
val_df['intent'].value_counts()
# Out:
# intent
# noresponse             8698
# support                2110
# smokefree              1024
# greetings               610
# cravings                482
# quitdate                427
# health                  283
# fail                    258
# nrt_itworks             205
# weightgain              177
# stress                  169
# savingmoney             152
# nrt_howtouse            118
# cigsmell                109
# nrt_don'twork           102
# scared                   98
# smokingless              95
# nrt_dreams               86
# ecigs                    68
# nrt_stickissue           63
# tiredness                51
# nrt_skinirritation       51
# nrt_mouthirritation      46
# nrt_nauseous             41
# nrt_od                   27
# Name: count, dtype: int64

# %%
test['intent'].value_counts()
# Out:
# intent
# noresponse             9664
# support                1983
# smokefree               818
# greetings               490
# quitdate                318
# cravings                267
# health                  265
# weightgain              167
# fail                    152
# stress                  148
# nrt_itworks             135
# nrt_howtouse            105
# savingmoney              90
# nrt_stickissue           83
# scared                   83
# cigsmell                 76
# ecigs                    73
# nrt_don'twork            72
# nrt_dreams               54
# tiredness                43
# nrt_skinirritation       35
# smokingless              33
# nrt_nauseous             23
# nrt_mouthirritation      21
# nrt_od                   21
# Name: count, dtype: int64
